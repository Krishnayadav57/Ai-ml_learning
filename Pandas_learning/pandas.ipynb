# %%
import pandas as pd

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# To store and 1d in pandas

# %%
list1 = ["A","B","C","D","E"]
series1= pd.Series(list1)

# %%
series1
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E
# dtype: object

# %%
list1 = ["A","B","C","D","E"]
series1= pd.Series(list1)

# %%
array1 = np.random.randint(20,25, size=(10))
array1
# Out:
# array([23, 22, 22, 23, 24, 20, 24, 21, 24, 20])

# %%
series2 = pd.Series(array1)

# %%
series2
# Out:
# 0    23
# 1    22
# 2    22
# 3    23
# 4    24
# 5    20
# 6    24
# 7    21
# 8    24
# 9    20
# dtype: int64

# %%
series3 = pd.Series(np.random.randint(20,25, size=(10)))
series3
# Out:
# 0    24
# 1    21
# 2    21
# 3    22
# 4    21
# 5    20
# 6    22
# 7    20
# 8    20
# 9    23
# dtype: int64

# %%
series2+series3
# Out:
# 0    47
# 1    43
# 2    43
# 3    45
# 4    45
# 5    40
# 6    46
# 7    41
# 8    44
# 9    43
# dtype: int64

# %%
series2*series3
# Out:
# 0    552
# 1    462
# 2    462
# 3    506
# 4    504
# 5    400
# 6    528
# 7    420
# 8    480
# 9    460
# dtype: int64

# %%
series2/series3
# Out:
# 0    0.958333
# 1    1.047619
# 2    1.047619
# 3    1.045455
# 4    1.142857
# 5    1.000000
# 6    1.090909
# 7    1.050000
# 8    1.200000
# 9    0.869565
# dtype: float64

# %% [markdown]
# # data frame

# %%
students = ["student1","student2","student3","student4","student5"]
rollno = ['1','2','3','4','5']
scores = [45,67,78,89,45]

# %%
record = {
    "student":students,
    "rollno":rollno,
    "scores":scores
    }

# %%
record
# Out:
# {'student': ['student1', 'student2', 'student3', 'student4', 'student5'],
#  'rollno': ['1', '2', '3', '4', '5'],
#  'scores': [45, 67, 78, 89, 45]}

# %%
record_df = pd.DataFrame(record)
record_df
# Out:
#     student rollno  scores
# 0  student1      1      45
# 1  student2      2      67
# 2  student3      3      78
# 3  student4      4      89
# 4  student5      5      45

# %%
record_df.set_index(["rollno"]) # index
# Out:
#          student  scores
# rollno
# 1       student1      45
# 2       student2      67
# 3       student3      78
# 4       student4      89
# 5       student5      45

# %%
dict1 = {
    "A":[12,13,14,15,16],
    "B":[13,14,15,16,17],
    "C":[14,15,16,17,18],
    "D":[15,16,17,18,19]
}

# %%
df_1 = pd.DataFrame(dict1)

# %%
df_1
# Out:
#     A   B   C   D
# 0  12  13  14  15
# 1  13  14  15  16
# 2  14  15  16  17
# 3  15  16  17  18
# 4  16  17  18  19

# %% [markdown]
# to see columns in df_1

# %%
df_1.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %% [markdown]
# ### Accessing the desired columns features

# %%
df_1["A"]
# Out:
# 0    12
# 1    13
# 2    14
# 3    15
# 4    16
# Name: A, dtype: int64

# %%
df_1[["A","B"]]
# Out:
#     A   B
# 0  12  13
# 1  13  14
# 2  14  15
# 3  15  16
# 4  16  17

# %%
df_1["E"] =  df_1["A"]+df_1["B"]+df_1["C"]+df_1["D"]

# %%
df_1
# Out:
#     A   B   C   D   E
# 0  12  13  14  15  54
# 1  13  14  15  16  58
# 2  14  15  16  17  62
# 3  15  16  17  18  66
# 4  16  17  18  19  70

# %%
df_1["F"] = df_1["E"]/4
df_1
# Out:
#     A   B   C   D   E     F
# 0  12  13  14  15  54  13.5
# 1  13  14  15  16  58  14.5
# 2  14  15  16  17  62  15.5
# 3  15  16  17  18  66  16.5
# 4  16  17  18  19  70  17.5

# %% [markdown]
# info() method

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       5 non-null      int64
#  1   B       5 non-null      int64
#  2   C       5 non-null      int64
#  3   D       5 non-null      int64
#  4   E       5 non-null      int64
#  5   F       5 non-null      float64
# dtypes: float64(1), int64(5)
# memory usage: 372.0 bytes

# %%
dict2={
    "students":["student1","student2","student3","student4","student5","student6","student7"],
    "rollno":['005','006',np.nan,'005','011','012','013'],
    "gender":["male",np.nan,"female","female","male","female","female"],
    "mark_obtained":[65,66,34,56,20,np.nan,56]

}

# %%
dict2
# Out:
# {'students': ['student1',
#   'student2',
#   'student3',
#   'student4',
#   'student5',
#   'student6',
#   'student7'],
#  'rollno': ['005', '006', nan, '005', '011', '012', '013'],
#  'gender': ['male', nan, 'female', 'female', 'male', 'female', 'female'],
#  'mark_obtained': [65, 66, 34, 56, 20, nan, 56]}

# %%
student_df = pd.DataFrame(dict2)

# %%
student_df
# Out:
#    students rollno  gender  mark_obtained
# 0  student1    005    male           65.0
# 1  student2    006     NaN           66.0
# 2  student3    NaN  female           34.0
# 3  student4    005  female           56.0
# 4  student5    011    male           20.0
# 5  student6    012  female            NaN
# 6  student7    013  female           56.0

# %% [markdown]
# ### To check  the null value

# %%
student_df.isnull()
# Out:
#    students  rollno  gender  mark_obtained
# 0     False   False   False          False
# 1     False   False    True          False
# 2     False    True   False          False
# 3     False   False   False          False
# 4     False   False   False          False
# 5     False   False   False           True
# 6     False   False   False          False

# %%
student_df.isnull().sum()
# Out:
# students         0
# rollno           1
# gender           1
# mark_obtained    1
# dtype: int64

# %%
student_df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Remove the dupicate value

# %%
student_df.drop_duplicates()
# Out:
#    students rollno  gender  mark_obtained
# 0  student1    005    male           65.0
# 1  student2    006     NaN           66.0
# 2  student3    NaN  female           34.0
# 3  student4    005  female           56.0
# 4  student5    011    male           20.0
# 5  student6    012  female            NaN
# 6  student7    013  female           56.0

# %%
student_df.dropna()
# Out:
#    students rollno  gender  mark_obtained
# 0  student1    005    male           65.0
# 3  student4    005  female           56.0
# 4  student5    011    male           20.0
# 6  student7    013  female           56.0

# %%
student_df
# Out:
#    students rollno  gender  mark_obtained
# 0  student1    005    male           65.0
# 1  student2    006     NaN           66.0
# 2  student3    NaN  female           34.0
# 3  student4    005  female           56.0
# 4  student5    011    male           20.0
# 5  student6    012  female            NaN
# 6  student7    013  female           56.0

# %%
marks_mean = student_df["mark_obtained"].mean()

# %%
marks_mean
# Out:
# np.float64(49.5)

# %%
student_df['gender'] = student_df['gender'].fillna('gender_mode')

# %%
student_df
# Out:
#    students rollno       gender  mark_obtained
# 0  student1    005         male           65.0
# 1  student2    006  gender_mode           66.0
# 2  student3    NaN       female           34.0
# 3  student4    005       female           56.0
# 4  student5    011         male           20.0
# 5  student6    012       female            NaN
# 6  student7    013       female           56.0

# %%
student_df['mark_obtained'] = student_df['mark_obtained'].fillna('marks_mean')
student_df
# Out:
#    students rollno       gender mark_obtained
# 0  student1    005         male          65.0
# 1  student2    006  gender_mode          66.0
# 2  student3    NaN       female          34.0
# 3  student4    005       female          56.0
# 4  student5    011         male          20.0
# 5  student6    012       female    marks_mean
# 6  student7    013       female          56.0

# %%
student_df
# Out:
#    students rollno       gender mark_obtained
# 0  student1    005         male          65.0
# 1  student2    006  gender_mode          66.0
# 2  student3    NaN       female          34.0
# 3  student4    005       female          56.0
# 4  student5    011         male          20.0
# 5  student6    012       female    marks_mean
# 6  student7    013       female          56.0

# %% [markdown]
# ### loading data to pandas

# %%
df = pd.read_csv(r"/content/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[["PassengerId", "Name", "Sex", "Survived"]].head(5)
# Out:
#    PassengerId                                               Name     Sex  \
# 0            1                            Braund, Mr. Owen Harris    male
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2            3                             Heikkinen, Miss. Laina  female
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4            5                           Allen, Mr. William Henry    male
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
df[["Name", "Sex", "Age"]].head(5)
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %% [markdown]
# ## Slicing in pandas(loc and iloc)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.loc[4:10, "Name":"Parch"]
# Out:
#                                                  Name     Sex   Age  SibSp  \
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
#
#     Parch
# 4       0
# 5       0
# 6       0
# 7       1
# 8       2
# 9       0
# 10      1

# %%
df.loc[10:20, "Ticket":"Embarked"]
# Out:
#        Ticket     Fare Cabin Embarked
# 10    PP 9549  16.7000    G6        S
# 11     113783  26.5500  C103        S
# 12  A/5. 2151   8.0500   NaN        S
# 13     347082  31.2750   NaN        S
# 14     350406   7.8542   NaN        S
# 15     248706  16.0000   NaN        S
# 16     382652  29.1250   NaN        Q
# 17     244373  13.0000   NaN        S
# 18     345763  18.0000   NaN        S
# 19       2649   7.2250   NaN        C
# 20     239865  26.0000   NaN        S

# %%
df.iloc[10:20, 8:]
# Out:
#        Ticket     Fare Cabin Embarked
# 10    PP 9549  16.7000    G6        S
# 11     113783  26.5500  C103        S
# 12  A/5. 2151   8.0500   NaN        S
# 13     347082  31.2750   NaN        S
# 14     350406   7.8542   NaN        S
# 15     248706  16.0000   NaN        S
# 16     382652  29.1250   NaN        Q
# 17     244373  13.0000   NaN        S
# 18     345763  18.0000   NaN        S
# 19       2649   7.2250   NaN        C

# %%
df.iloc[15:26, 2:8]
# Out:
#     Pclass                                               Name     Sex   Age  \
# 15       2                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0
# 16       3                               Rice, Master. Eugene    male   2.0
# 17       2                       Williams, Mr. Charles Eugene    male   NaN
# 18       3  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0
# 19       3                            Masselmani, Mrs. Fatima  female   NaN
# 20       2                               Fynney, Mr. Joseph J    male  35.0
# 21       2                              Beesley, Mr. Lawrence    male  34.0
# 22       3                        McGowan, Miss. Anna "Annie"  female  15.0
# 23       1                       Sloper, Mr. William Thompson    male  28.0
# 24       3                      Palsson, Miss. Torborg Danira  female   8.0
# 25       3  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0
#
#     SibSp  Parch
# 15      0      0
# 16      4      1
# ...

# %%
df[["Name", "Parch"]]
# Out:
#                                                   Name  Parch
# 0                              Braund, Mr. Owen Harris      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...      0
# 2                               Heikkinen, Miss. Laina      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0
# 4                             Allen, Mr. William Henry      0
# ..                                                 ...    ...
# 886                              Montvila, Rev. Juozas      0
# 887                       Graham, Miss. Margaret Edith      0
# 888           Johnston, Miss. Catherine Helen "Carrie"      2
# 889                              Behr, Mr. Karl Howell      0
# 890                                Dooley, Mr. Patrick      0
#
# [891 rows x 2 columns]

# %% [markdown]
# # Geting information about the data

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 125          126         1       3
# 350          351         0       3
# 299          300         1       1
# 413          414         0       2
# 193          194         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 125                     Nicola-Yarred, Master. Elias    male  12.0      1
# 350                           Odahl, Mr. Nils Martin    male  23.0      0
# 299  Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0      0
# 413                   Cunningham, Mr. Alfred Fleming    male   NaN      0
# 193                       Navratil, Master. Michel M    male   3.0      1
#
#      Parch    Ticket      Fare    Cabin Embarked
# 125      0      2651   11.2417      NaN        C
# 350      0      7267    9.2250      NaN        S
# 299      1  PC 17558  247.5208  B58 B60        C
# 413      0    239853    0.0000      NaN        S
# 193      1    230080   26.0000       F2        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ## Checking missing values

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df["Embarked"].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df["Embarked"].fillna("S", inplace=True)
# Out:
# /tmp/ipython-input-2591539637.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Embarked"].fillna("S", inplace=True)

# %%
age_mean = df["Age"].mean()
age_mean
# Out:
# np.float64(29.69911764705882)

# %%
embarked_mode = df["Embarked"].mode()[0]
embarked_mode
# Out:
# 'S'

# %%
df["Age"] = df["Age"].fillna(age_mean)
df["Embarked"] = df["Embarked"].fillna(embarked_mode)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
removing_columns = [["PassengerId", "Name", "Ticket"]]

# %%
df = df.drop(columns=removing_columns, errors="ignore")

# %%
if {"SibSp", "Parch"}.issubset(df.columns):
    df["Family_size"] = df["SibSp"] + df["Parch"] + 1
else:
    print("Missing columns:", {"SibSp", "Parch"} - set(df.columns))

# %%
df["Family_size"] = df["SibSp"] + df["Parch"] +1

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Family_size
# 0      0         A/5 21171   7.2500   NaN        S            2
# 1      0          PC 17599  71.2833   C85        C            2
# 2      0  STON/O2. 3101282   7.9250   NaN        S            1
# ...

# %%
df = df.drop(columns=["SibSp", "Parch"])

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#              Ticket     Fare Cabin Embarked  Family_size
# 0         A/5 21171   7.2500   NaN        S            2
# 1          PC 17599  71.2833   C85        C            2
# 2  STON/O2. 3101282   7.9250   NaN        S            1
# 3            113803  53.1000  C123        S            2
# 4            373450   8.0500   NaN        S            1

# %%
df1 = df.copy()

# %%
df1 = pd.get_dummies(df1, columns=["Embarked"], dtype=int)

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#              Ticket     Fare Cabin  Family_size  Embarked_C  Embarked_Q  \
# 0         A/5 21171   7.2500   NaN            2           0           0
# 1          PC 17599  71.2833   C85            2           1           0
# 2  STON/O2. 3101282   7.9250   NaN            1           0           0
# ...

# %%
df1 = pd.get_dummies(df1, columns=["Embarked"], dtype=int, drop_first=True)
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#              Ticket     Fare Cabin  Family_size  Embarked_Q  Embarked_S
# 0         A/5 21171   7.2500   NaN            2           0           1
# 1          PC 17599  71.2833   C85            2           0           0
# 2  STON/O2. 3101282   7.9250   NaN            1           0           1
# ...

# %%
def fare_category(fare):
    if fare <= 15:
        return "low"
    elif fare <= 40:
        return "medium"
    else:
        return "high"

# %%
df1["Fare_category"] = df1["Fare"].apply(fare_category)

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#              Ticket     Fare Cabin  Family_size  Embarked_Q  Embarked_S  \
# 0         A/5 21171   7.2500   NaN            2           0           1
# 1          PC 17599  71.2833   C85            2           0           0
# 2  STON/O2. 3101282   7.9250   NaN            1           0           1
# ...

# %% [markdown]
# ### Remove the Fare category column

# %%
df1 = df1.drop(columns=["Fare_category"])

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#              Ticket     Fare Cabin  Family_size  Embarked_Q  Embarked_S
# 0         A/5 21171   7.2500   NaN            2           0           1
# 1          PC 17599  71.2833   C85            2           0           0
# 2  STON/O2. 3101282   7.9250   NaN            1           0           1
# ...

# %%
df["Cabin"].values
# Out:
# array([nan, 'C85', nan, 'C123', nan, nan, 'E46', nan, nan, nan, 'G6',
#        'C103', nan, nan, nan, nan, nan, nan, nan, nan, nan, 'D56', nan,
#        'A6', nan, nan, nan, 'C23 C25 C27', nan, nan, nan, 'B78', nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, 'D33', nan, 'B30', 'C52', nan, nan, nan,
#        nan, nan, 'B28', 'C83', nan, nan, nan, 'F33', nan, nan, nan, nan,
#        nan, nan, nan, nan, 'F G73', nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, 'C23 C25 C27', nan, nan, nan, 'E31', nan,
#        nan, nan, 'A5', 'D10 D12', nan, nan, nan, nan, 'D26', nan, nan,
#        nan, nan, nan, nan, nan, 'C110', nan, nan, nan, nan, nan, nan, nan,
#        'B58 B60', nan, nan, nan, nan, 'E101', 'D26', nan, nan, nan,
#        'F E69', nan, nan, nan, nan, nan, nan, nan, 'D47', 'C123', nan,
#        'B86', nan, nan, nan, nan, nan, nan, nan, nan, 'F2', nan, nan,
# ...

# %% [markdown]
# ## Handling the null value in the cabin by filling 'yes' in the passenger having cabin otherwise 'No' if nan

# %%
df1["Has_cabin"] = np.where(df1["Cabin"].notna(), "Yes", "No")

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#              Ticket     Fare Cabin  Family_size  Embarked_Q  Embarked_S  \
# 0         A/5 21171   7.2500   NaN            2           0           1
# 1          PC 17599  71.2833   C85            2           0           0
# 2  STON/O2. 3101282   7.9250   NaN            1           0           1
# ...

# %%
## now removing the cabin column from the dataset

# %%
df1 = df1.drop(columns=["Cabin"])

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df1["Has_cabin"] = df1["Has_cabin"].map({"Yes":1, "No":0})

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#              Ticket     Fare  Family_size  Embarked_Q  Embarked_S  Has_cabin
# 0         A/5 21171   7.2500            2           0           1          0
# 1          PC 17599  71.2833            2           0           0          1
# 2  STON/O2. 3101282   7.9250            1           0           1          0
# ...

# %%
# df1 = df1.drop(columns=["Name"])

# %%
#df1 = df1.drop(columns=["Ticket"])

# %%
cleaned_df = df1.copy()

# %%
cleaned_df
# Out:
#      PassengerId  Survived  Pclass     Sex        Age     Fare  Family_size  \
# 0              1         0       3    male  22.000000   7.2500            2
# 1              2         1       1  female  38.000000  71.2833            2
# 2              3         1       3  female  26.000000   7.9250            1
# 3              4         1       1  female  35.000000  53.1000            2
# 4              5         0       3    male  35.000000   8.0500            1
# ..           ...       ...     ...     ...        ...      ...          ...
# 886          887         0       2    male  27.000000  13.0000            1
# 887          888         1       1  female  19.000000  30.0000            1
# 888          889         0       3  female  29.699118  23.4500            4
# 889          890         1       1    male  26.000000  30.0000            1
# 890          891         0       3    male  32.000000   7.7500            1
#
#      Embarked_Q  Embarked_S  Has_cabin
# ...

# %%
cleaned_df.to_csv("cleaned_titanic.csv")
